# %%
def update_learning_rate(i, splitNN):
    lr_a = 0.3
    if i > 200:
        lr_a = 0.05
    if i > 400:
        lr_a = 0.01
    if i > 500:
        lr_a = 0.001
    optimizers = [
        (optim.SGD(models[location.id].parameters(), lr=lr_a,), location)
        for location in model_locations
    ]
    
    splitNN.set_lr(optimizers)
    return

EPOCHS = 200
SUBSET_UPDATE_PROB = 0.2
PADDING_METHOD = "mean"
LEARNING_RATE = 0.3
GROUP_TESTING_ROUNDS = 5
res = []

import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
from torch import nn, optim
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor

import syft as sy
import random
from time import process_time

from src.psi.util import Client, Server
from src.discrete_splitnn import DiscreteSplitNN
from src.utils import add_ids
from src.discrete_distribute_data import DiscreteDistributeMNIST

hook = sy.TorchHook(torch)

# Data preprocessing
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])
trainset = datasets.MNIST('mnist', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64
                                          , shuffle=True)

# create some workers
client_1 = sy.VirtualWorker(hook, id="client_1")
client_2 = sy.VirtualWorker(hook, id="client_2")
client_3 = sy.VirtualWorker(hook, id="client_3")
client_4 = sy.VirtualWorker(hook, id="client_4")
server = sy.VirtualWorker(hook, id= "server") 

data_owners = (client_1, client_2, client_3, client_4)
model_locations = [client_1, client_2, client_3, client_4, server]

#Split each image and send one part to client_1, and other to client_2
distributed_trainloader = DiscreteDistributeMNIST(data_owners=data_owners, data_loader=trainloader)

torch.manual_seed(0)

# Define our model segments

input_size= [28*7, 28*7, 28*7, 28*7]
hidden_sizes= {"client_1": [128, 64], "client_2":[128, 64], "client_3": [128, 64], "client_4":[128, 64], "server":[256, 128]}
output_size = 10

models = {
    "client_1": nn.Sequential(
                nn.Linear(input_size[0], hidden_sizes["client_1"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_1"][0], hidden_sizes["client_1"][1]),
                nn.ReLU(),
    ),
    "client_2":  nn.Sequential(
                nn.Linear(input_size[1], hidden_sizes["client_2"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_2"][0], hidden_sizes["client_2"][1]),
                nn.ReLU(),
    ),
    "client_3":  nn.Sequential(
                nn.Linear(input_size[2], hidden_sizes["client_3"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_3"][0], hidden_sizes["client_3"][1]),
                nn.ReLU(),
    ),
    "client_4":  nn.Sequential(
                nn.Linear(input_size[3], hidden_sizes["client_4"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_4"][0], hidden_sizes["client_4"][1]),
                nn.ReLU(),
    ),
    "server": nn.Sequential(
                nn.Linear(hidden_sizes["server"][0], hidden_sizes["server"][1]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["server"][1], 10),
                nn.LogSoftmax(dim=1)
    )
}

# Create optimisers for each segment and link to them
optimizers = [
    (optim.SGD(models[location.id].parameters(), lr=LEARNING_RATE,), location)
    for location in model_locations
]

for location in model_locations:
    models[location.id].send(location)


#Instantiate a SpliNN class with our distributed segments and their respective optimizers
splitNN = DiscreteSplitNN(models, server, data_owners, optimizers, distributed_trainloader, k=10, n_selected=2, padding_method=PADDING_METHOD)

distributed_trainloader.generate_subdata()
s = process_time()
splitNN.group_testing(GROUP_TESTING_ROUNDS)
print('group testing: ' + str(process_time() - s))
test_perf = []
performance = []
print(len(distributed_trainloader.distributed_subdata))
print(len(distributed_trainloader.test_set))
for i in range(EPOCHS):
    s = process_time()
    if (i > 0) and (i % 5000 == 0):
        plt.plot(range(1, i+1), performance)
        plt.ylabel('Training loss')
        plt.xlabel('Epoch')
        plt.ylim([0,2.5])
        plt.show()

        plt.plot(range(1, i+1), test_perf)
        plt.ylabel('Test loss')
        plt.xlabel('Epoch')
        plt.ylim([0,2.5])
        plt.show()
    running_loss = 0
    test_loss = 0
    if (random.random() < SUBSET_UPDATE_PROB):
        distributed_trainloader.generate_subdata()
        splitNN.group_testing(GROUP_TESTING_ROUNDS)
    
    #iterate over each datapoint 
    for _, data_ptr, label in distributed_trainloader.distributed_subdata:
        
        #send labels to server's location for training
        label = label.send(server)
        
        loss = splitNN.train(data_ptr, label)
        running_loss += loss
    
    for data_ptr, label in distributed_trainloader.test_set:
        label = label.send(server)
        
        loss = splitNN.eval(data_ptr, label)
        test_loss += loss
    
    test_perf.append((test_loss/len(distributed_trainloader.test_set)).item())
    performance.append((running_loss/len(distributed_trainloader.distributed_subdata)).item())
    print("Epoch {} - Training loss: {}".format(i, running_loss/len(distributed_trainloader.distributed_subdata)))
    print("Epoch {} - Test loss: {}".format(i, test_loss/len(distributed_trainloader.test_set)))
    update_learning_rate(i, splitNN)


res.append(performance)
plt.plot(range(1, EPOCHS+1), performance)
plt.ylabel('Training loss')
plt.xlabel('Epoch')
plt.ylim([0,2.5])
plt.show()

plt.plot(range(1, EPOCHS+1), test_perf)
plt.ylabel('Test loss')
plt.xlabel('Epoch')
plt.ylim([0,2.5])
plt.show()
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process
# group testing: 7.927299999899162e-05
# 93
# 50
# Epoch 0 - Training loss: 2.2422971725463867
# Epoch 0 - Test loss: 2.1218338012695312
# Epoch 1 - Training loss: 1.9146274328231812
# Epoch 1 - Test loss: 1.6846140623092651
# Epoch 2 - Training loss: 1.5477821826934814
# Epoch 2 - Test loss: 1.3803260326385498
# Epoch 3 - Training loss: 1.3253504037857056
# Epoch 3 - Test loss: 1.204054355621338
# Epoch 4 - Training loss: 1.1960409879684448
# Epoch 4 - Test loss: 1.1034746170043945
# Epoch 5 - Training loss: 1.1167306900024414
# Epoch 5 - Test loss: 1.040459394454956
# Epoch 6 - Training loss: 1.0623148679733276
# Epoch 6 - Test loss: 0.9957284331321716
# Epoch 7 - Training loss: 1.0211435556411743
# Epoch 7 - Test loss: 0.961371660232544
# Epoch 8 - Training loss: 0.9883607625961304
# Epoch 8 - Test loss: 0.9332465529441833
# Epoch 9 - Training loss: 0.9608021974563599
# Epoch 9 - Test loss: 0.9100744128227234
# Epoch 10 - Training loss: 0.9368934035301208
# Epoch 10 - Test loss: 0.8893222808837891
# Epoch 11 - Training loss: 1.23600172996521
# Epoch 11 - Test loss: 1.0412471294403076
# Epoch 12 - Training loss: 2.118035316467285
# Epoch 12 - Test loss: 1.7604528665542603
# Epoch 13 - Training loss: 1.5948776006698608
# Epoch 13 - Test loss: 1.4858893156051636
# Epoch 14 - Training loss: 1.3622150421142578
# Epoch 14 - Test loss: 1.3459341526031494
# Epoch 15 - Training loss: 1.2395721673965454
# Epoch 15 - Test loss: 1.2373868227005005
# Epoch 16 - Training loss: 1.1557362079620361
# Epoch 16 - Test loss: 1.1586273908615112
# Epoch 17 - Training loss: 1.098168969154358
# Epoch 17 - Test loss: 1.1070163249969482
# Epoch 18 - Training loss: 1.0552681684494019
# Epoch 18 - Test loss: 1.0678766965866089
# Epoch 19 - Training loss: 1.0214152336120605
# Epoch 19 - Test loss: 1.0414443016052246
# Epoch 20 - Training loss: 0.9943985342979431
# Epoch 20 - Test loss: 1.0323293209075928
# Epoch 21 - Training loss: 1.1917449235916138
# Epoch 21 - Test loss: 0.9452160000801086
# Epoch 22 - Training loss: 1.0047385692596436
# Epoch 22 - Test loss: 0.8996981978416443
# Epoch 23 - Training loss: 0.9516945481300354
# Epoch 23 - Test loss: 0.8811836242675781
# Epoch 24 - Training loss: 0.9192830324172974
# Epoch 24 - Test loss: 0.8701826333999634
# Epoch 25 - Training loss: 0.8916192650794983
# Epoch 25 - Test loss: 0.8682169914245605
# Epoch 26 - Training loss: 0.8721471428871155
# Epoch 26 - Test loss: 0.8581743836402893
# Epoch 27 - Training loss: 0.8522524237632751
# Epoch 27 - Test loss: 0.8487034440040588
# Epoch 28 - Training loss: 0.838513970375061
# Epoch 28 - Test loss: 0.8437613844871521
# Epoch 29 - Training loss: 0.8214868903160095
# Epoch 29 - Test loss: 0.8371965289115906
# Epoch 30 - Training loss: 0.8090485334396362
# Epoch 30 - Test loss: 0.8259202837944031
# Epoch 31 - Training loss: 0.7964659929275513
# Epoch 31 - Test loss: 0.8188090324401855
# Epoch 32 - Training loss: 0.8594910502433777
# Epoch 32 - Test loss: 0.8067184686660767
# Epoch 33 - Training loss: 0.8344641327857971
# Epoch 33 - Test loss: 0.7956787347793579
# Epoch 34 - Training loss: 0.8179073929786682
# Epoch 34 - Test loss: 0.7927300333976746
# Epoch 35 - Training loss: 0.8028052449226379
# Epoch 35 - Test loss: 0.7878431677818298
# Epoch 36 - Training loss: 0.7875122427940369
# Epoch 36 - Test loss: 0.7790339589118958
# Epoch 37 - Training loss: 0.7741678357124329
# Epoch 37 - Test loss: 0.7689546942710876
# Epoch 38 - Training loss: 0.760212242603302
# Epoch 38 - Test loss: 0.7594030499458313
# Epoch 39 - Training loss: 0.7494904398918152
# Epoch 39 - Test loss: 0.7491098642349243
# Epoch 40 - Training loss: 0.738528311252594
# Epoch 40 - Test loss: 0.743480920791626
# Epoch 41 - Training loss: 0.728358268737793
# Epoch 41 - Test loss: 0.7360472083091736
# Epoch 42 - Training loss: 0.7190196514129639
# Epoch 42 - Test loss: 0.7282063961029053
# Epoch 43 - Training loss: 0.7099142074584961
# Epoch 43 - Test loss: 0.7227944731712341
# Epoch 44 - Training loss: 0.7019615769386292
# Epoch 44 - Test loss: 0.7157960534095764
# Epoch 45 - Training loss: 0.6939802169799805
# Epoch 45 - Test loss: 0.7115176916122437
# Epoch 46 - Training loss: 0.6863052248954773
# Epoch 46 - Test loss: 0.7096000909805298
# Epoch 47 - Training loss: 0.6780347228050232
# Epoch 47 - Test loss: 0.7064387798309326
# Epoch 48 - Training loss: 0.6710873246192932
# Epoch 48 - Test loss: 0.7045320272445679
# Epoch 49 - Training loss: 0.6647173166275024
# Epoch 49 - Test loss: 0.6994994282722473
# Epoch 50 - Training loss: 0.6580052971839905
# Epoch 50 - Test loss: 0.6969162821769714
# Epoch 51 - Training loss: 0.650816023349762
# Epoch 51 - Test loss: 0.6939716935157776
# Epoch 52 - Training loss: 0.6442734599113464
# Epoch 52 - Test loss: 0.691459059715271
# Epoch 53 - Training loss: 0.6271020174026489
# Epoch 53 - Test loss: 0.5763071775436401
# Epoch 54 - Training loss: 0.5502193570137024
# Epoch 54 - Test loss: 0.5415573716163635
# Epoch 55 - Training loss: 0.5119061470031738
# Epoch 55 - Test loss: 0.5225562453269958
# Epoch 56 - Training loss: 0.487843781709671
# Epoch 56 - Test loss: 0.5119905471801758
# Epoch 57 - Training loss: 0.4684143364429474
# Epoch 57 - Test loss: 0.49628010392189026
# Epoch 58 - Training loss: 0.4525880813598633
# Epoch 58 - Test loss: 0.4880659878253937
# Epoch 59 - Training loss: 0.43833139538764954
# Epoch 59 - Test loss: 0.4797130227088928
# Epoch 60 - Training loss: 0.4259762465953827
# Epoch 60 - Test loss: 0.4788696765899658
# Epoch 61 - Training loss: 0.4150862991809845
# Epoch 61 - Test loss: 0.4724380075931549
# Epoch 62 - Training loss: 0.40468713641166687
# Epoch 62 - Test loss: 0.46669426560401917
# Epoch 63 - Training loss: 0.39555856585502625
# Epoch 63 - Test loss: 0.4609488546848297
# Epoch 64 - Training loss: 0.3867863416671753
# Epoch 64 - Test loss: 0.45662209391593933
# Epoch 65 - Training loss: 0.37820151448249817
# Epoch 65 - Test loss: 0.4530705213546753
# Epoch 66 - Training loss: 0.37060537934303284
# Epoch 66 - Test loss: 0.4498242139816284
# Epoch 67 - Training loss: 0.3634786903858185
# Epoch 67 - Test loss: 0.44690659642219543
# Epoch 68 - Training loss: 0.35607099533081055
# Epoch 68 - Test loss: 0.4433428943157196
# Epoch 69 - Training loss: 0.9368085265159607
# Epoch 69 - Test loss: 0.7534430623054504
# Epoch 70 - Training loss: 0.8264032602310181
# Epoch 70 - Test loss: 0.7429817318916321
# Epoch 71 - Training loss: 0.787594199180603
# Epoch 71 - Test loss: 0.7338302135467529
# Epoch 72 - Training loss: 0.7622675895690918
# Epoch 72 - Test loss: 0.7213115692138672
# Epoch 73 - Training loss: 0.7436206936836243
# Epoch 73 - Test loss: 0.7149770259857178
# Epoch 74 - Training loss: 0.7274782061576843
# Epoch 74 - Test loss: 0.7062398791313171
# Epoch 75 - Training loss: 0.7128553986549377
# Epoch 75 - Test loss: 0.7022683620452881
# Epoch 76 - Training loss: 0.6989050507545471
# Epoch 76 - Test loss: 0.6978127360343933
# Epoch 77 - Training loss: 0.6904771327972412
# Epoch 77 - Test loss: 0.6938236355781555
# Epoch 78 - Training loss: 0.6784858703613281
# Epoch 78 - Test loss: 0.6891236305236816
# Epoch 79 - Training loss: 0.6691522002220154
# Epoch 79 - Test loss: 0.6873413920402527
# Epoch 80 - Training loss: 2.1179606914520264
# Epoch 80 - Test loss: 1.840029239654541
# Epoch 81 - Training loss: 1.137937307357788
# Epoch 81 - Test loss: 0.8938316106796265
# Epoch 82 - Training loss: 0.950445294380188
# Epoch 82 - Test loss: 0.8928905725479126
# Epoch 83 - Training loss: 1.9710073471069336
# Epoch 83 - Test loss: 1.7661902904510498
# Epoch 84 - Training loss: 1.8364423513412476
# Epoch 84 - Test loss: 1.7062599658966064
# Epoch 85 - Training loss: 1.7919589281082153
# Epoch 85 - Test loss: 1.696494698524475
# Epoch 86 - Training loss: 1.7617261409759521
# Epoch 86 - Test loss: 1.640559196472168
# Epoch 87 - Training loss: 1.7460753917694092
# Epoch 87 - Test loss: 1.6224110126495361
# Epoch 88 - Training loss: 1.7058638334274292
# Epoch 88 - Test loss: 1.628943681716919
# Epoch 89 - Training loss: 1.7059284448623657
# Epoch 89 - Test loss: 1.6933218240737915
# Epoch 90 - Training loss: 1.6823909282684326
# Epoch 90 - Test loss: 1.6186301708221436
# Epoch 91 - Training loss: 1.6639546155929565
# Epoch 91 - Test loss: 1.5840727090835571
# Epoch 92 - Training loss: 1.6944580078125
# Epoch 92 - Test loss: 1.6545411348342896
# Epoch 93 - Training loss: 0.9579694271087646
# Epoch 93 - Test loss: 0.7837137579917908
# Epoch 94 - Training loss: 0.8609851598739624
# Epoch 94 - Test loss: 0.7511293888092041
# Epoch 95 - Training loss: 0.8218759298324585
# Epoch 95 - Test loss: 0.7350227236747742
# Epoch 96 - Training loss: 0.7939159870147705
# Epoch 96 - Test loss: 0.7195799350738525
# Epoch 97 - Training loss: 0.7708234190940857
# Epoch 97 - Test loss: 0.7060192227363586
# Epoch 98 - Training loss: 0.7503451704978943
# Epoch 98 - Test loss: 0.7090820074081421
# Epoch 99 - Training loss: 0.7339286804199219
# Epoch 99 - Test loss: 0.6979122757911682
# Epoch 100 - Training loss: 0.7170590162277222
# Epoch 100 - Test loss: 0.688194990158081
# Epoch 101 - Training loss: 0.7044826745986938
# Epoch 101 - Test loss: 0.677361011505127
# Epoch 102 - Training loss: 0.6892070174217224
# Epoch 102 - Test loss: 0.6596965789794922
# Epoch 103 - Training loss: 0.6779206395149231
# Epoch 103 - Test loss: 0.6503609418869019
# Epoch 104 - Training loss: 0.6653345227241516
# Epoch 104 - Test loss: 0.650383710861206
# Epoch 105 - Training loss: 0.6549885869026184
# Epoch 105 - Test loss: 0.6427070498466492
# Epoch 106 - Training loss: 0.6440305113792419
# Epoch 106 - Test loss: 0.6350837349891663
# Epoch 107 - Training loss: 0.850039541721344
# Epoch 107 - Test loss: 0.7678601741790771
# Epoch 108 - Training loss: 0.6730648875236511
# Epoch 108 - Test loss: 0.6107636094093323
# Epoch 109 - Training loss: 0.6481967568397522
# Epoch 109 - Test loss: 0.602944552898407
# Epoch 110 - Training loss: 0.6312010288238525
# Epoch 110 - Test loss: 0.6002500653266907
# Epoch 111 - Training loss: 0.6195049285888672
# Epoch 111 - Test loss: 0.5938921570777893
# Epoch 112 - Training loss: 0.8940291404724121
# Epoch 112 - Test loss: 0.7269485592842102
# Epoch 113 - Training loss: 0.7786812782287598
# Epoch 113 - Test loss: 0.6776540279388428
# Epoch 114 - Training loss: 0.7763534188270569
# Epoch 114 - Test loss: 0.690501868724823
# Epoch 115 - Training loss: 0.7503105998039246
# Epoch 115 - Test loss: 0.6754624843597412
# Epoch 116 - Training loss: 0.7306661605834961
# Epoch 116 - Test loss: 0.6703983545303345
# Epoch 117 - Training loss: 0.7136078476905823
# Epoch 117 - Test loss: 0.6649919152259827
# Epoch 118 - Training loss: 0.8669014573097229
# Epoch 118 - Test loss: 0.7484618425369263
# Epoch 119 - Training loss: 1.8439629077911377
# Epoch 119 - Test loss: 1.657798171043396
# Epoch 120 - Training loss: 1.6979098320007324
# Epoch 120 - Test loss: 1.6949572563171387
# Epoch 121 - Training loss: 1.662843942642212
# Epoch 121 - Test loss: 1.6278343200683594
# Epoch 122 - Training loss: 1.63849675655365
# Epoch 122 - Test loss: 1.6348987817764282
# Epoch 123 - Training loss: 0.46412742137908936
# Epoch 123 - Test loss: 0.43491730093955994
# Epoch 124 - Training loss: 1.656262755393982
# Epoch 124 - Test loss: 1.59757399559021
# Epoch 125 - Training loss: 1.618446946144104
# Epoch 125 - Test loss: 1.6528478860855103
# Epoch 126 - Training loss: 0.41938695311546326
# Epoch 126 - Test loss: 0.3883017301559448
# Epoch 127 - Training loss: 0.38502511382102966
# Epoch 127 - Test loss: 0.3810085952281952
# Epoch 128 - Training loss: 0.36839306354522705
# Epoch 128 - Test loss: 0.3741360902786255
# Epoch 129 - Training loss: 0.6494443416595459
# Epoch 129 - Test loss: 0.5804603695869446
# Epoch 130 - Training loss: 0.6014863848686218
# Epoch 130 - Test loss: 0.5650227069854736
# Epoch 131 - Training loss: 0.5815091729164124
# Epoch 131 - Test loss: 0.5573105216026306
# Epoch 132 - Training loss: 0.567823052406311
# Epoch 132 - Test loss: 0.5551899075508118
# Epoch 133 - Training loss: 0.7375228404998779
# Epoch 133 - Test loss: 0.6939179301261902
# Epoch 134 - Training loss: 0.6865600347518921
# Epoch 134 - Test loss: 0.6929436326026917
# Epoch 135 - Training loss: 1.6810648441314697
# Epoch 135 - Test loss: 1.58371901512146
# Epoch 136 - Training loss: 0.40859052538871765
# Epoch 136 - Test loss: 0.41679003834724426
# Epoch 137 - Training loss: 0.3733179271221161
# Epoch 137 - Test loss: 0.40549764037132263
# Epoch 138 - Training loss: 0.3568267524242401
# Epoch 138 - Test loss: 0.39977481961250305
# Epoch 139 - Training loss: 0.6321650147438049
# Epoch 139 - Test loss: 0.56709885597229
# Epoch 140 - Training loss: 0.6043696999549866
# Epoch 140 - Test loss: 0.5626783967018127
# Epoch 141 - Training loss: 0.5895877480506897
# Epoch 141 - Test loss: 0.5571776628494263
# Epoch 142 - Training loss: 0.5770890712738037
# Epoch 142 - Test loss: 0.5536781549453735
# Epoch 143 - Training loss: 0.5671570301055908
# Epoch 143 - Test loss: 0.5489507913589478
# Epoch 144 - Training loss: 0.5581379532814026
# Epoch 144 - Test loss: 0.5481822490692139
# Epoch 145 - Training loss: 0.750322699546814
# Epoch 145 - Test loss: 0.6523720026016235
# Epoch 146 - Training loss: 0.7087798714637756
# Epoch 146 - Test loss: 0.6294713020324707
# Epoch 147 - Training loss: 0.582718551158905
# Epoch 147 - Test loss: 0.5353158116340637
# Epoch 148 - Training loss: 0.5480533242225647
# Epoch 148 - Test loss: 0.5320699214935303
# Epoch 149 - Training loss: 0.5352813005447388
# Epoch 149 - Test loss: 0.5282814502716064
# Epoch 150 - Training loss: 0.35520967841148376
# Epoch 150 - Test loss: 0.35485202074050903
# Epoch 151 - Training loss: 1.7035237550735474
# Epoch 151 - Test loss: 1.5672402381896973
# Epoch 152 - Training loss: 1.6202771663665771
# Epoch 152 - Test loss: 1.5370806455612183
# Epoch 153 - Training loss: 1.6100248098373413
# Epoch 153 - Test loss: 1.5209593772888184
# Epoch 154 - Training loss: 1.6019293069839478
# Epoch 154 - Test loss: 1.5595968961715698
# Epoch 155 - Training loss: 1.5953009128570557
# Epoch 155 - Test loss: 1.557075023651123
# Epoch 156 - Training loss: 0.7305247783660889
# Epoch 156 - Test loss: 0.6737747192382812
# Epoch 157 - Training loss: 0.7002023458480835
# Epoch 157 - Test loss: 0.6997935771942139
# Epoch 158 - Training loss: 0.6728060245513916
# Epoch 158 - Test loss: 0.6804476976394653
# Epoch 159 - Training loss: 0.5999394059181213
# Epoch 159 - Test loss: 0.519793689250946
# Epoch 160 - Training loss: 0.5614962577819824
# Epoch 160 - Test loss: 0.5098961591720581
# Epoch 161 - Training loss: 0.5450481176376343
# Epoch 161 - Test loss: 0.5074496865272522
# Epoch 162 - Training loss: 0.5318706631660461
# Epoch 162 - Test loss: 0.5071961283683777
# Epoch 163 - Training loss: 0.694286584854126
# Epoch 163 - Test loss: 0.6437749266624451
# Epoch 164 - Training loss: 0.7040689587593079
# Epoch 164 - Test loss: 0.6389989852905273
# Epoch 165 - Training loss: 0.6844562888145447
# Epoch 165 - Test loss: 0.6297968626022339
# Epoch 166 - Training loss: 0.6694230437278748
# Epoch 166 - Test loss: 0.6192429065704346
# Epoch 167 - Training loss: 0.6562258005142212
# Epoch 167 - Test loss: 0.6169432997703552
# Epoch 168 - Training loss: 0.6473610997200012
# Epoch 168 - Test loss: 0.6170706748962402
# Epoch 169 - Training loss: 0.6369537115097046
# Epoch 169 - Test loss: 0.6173315644264221
# Epoch 170 - Training loss: 1.6096076965332031
# Epoch 170 - Test loss: 1.6509007215499878
# Epoch 171 - Training loss: 1.5731651782989502
# Epoch 171 - Test loss: 1.6327553987503052
# Epoch 172 - Training loss: 1.5550566911697388
# Epoch 172 - Test loss: 1.6076480150222778
# Epoch 173 - Training loss: 1.5525269508361816
# Epoch 173 - Test loss: 1.6457127332687378
# Epoch 174 - Training loss: 1.5497980117797852
# Epoch 174 - Test loss: 1.584806203842163
# Epoch 175 - Training loss: 1.5222984552383423
# Epoch 175 - Test loss: 1.618776559829712
# Epoch 176 - Training loss: 1.5206749439239502
# Epoch 176 - Test loss: 1.5987147092819214
# Epoch 177 - Training loss: 1.5158257484436035
# Epoch 177 - Test loss: 1.5917727947235107
# Epoch 178 - Training loss: 1.5172984600067139
# Epoch 178 - Test loss: 1.5839757919311523
# Epoch 179 - Training loss: 1.5048960447311401
# Epoch 179 - Test loss: 1.5879340171813965
# Epoch 180 - Training loss: 1.5005749464035034
# Epoch 180 - Test loss: 1.5636470317840576
# Epoch 181 - Training loss: 1.4936168193817139
# Epoch 181 - Test loss: 1.5706987380981445
# Epoch 182 - Training loss: 1.4867719411849976
# Epoch 182 - Test loss: 1.5362133979797363
# Epoch 183 - Training loss: 1.4832520484924316
# Epoch 183 - Test loss: 1.572540283203125
# Epoch 184 - Training loss: 0.5727382898330688
# Epoch 184 - Test loss: 0.5217381119728088
# Epoch 185 - Training loss: 0.5398986339569092
# Epoch 185 - Test loss: 0.5197731256484985
# Epoch 186 - Training loss: 0.5248366594314575
# Epoch 186 - Test loss: 0.5179226398468018
# Epoch 187 - Training loss: 0.5136817693710327
# Epoch 187 - Test loss: 0.512518048286438
# Epoch 188 - Training loss: 0.5052198767662048
# Epoch 188 - Test loss: 0.5115249752998352
# Epoch 189 - Training loss: 0.49548426270484924
# Epoch 189 - Test loss: 0.5097658634185791
# Epoch 190 - Training loss: 0.48690173029899597
# Epoch 190 - Test loss: 0.5093446969985962
# Epoch 191 - Training loss: 0.6792449951171875
# Epoch 191 - Test loss: 0.6548071503639221
# Epoch 192 - Training loss: 0.6609100103378296
# Epoch 192 - Test loss: 0.6673105359077454
# Epoch 193 - Training loss: 0.6407729387283325
# Epoch 193 - Test loss: 0.6564825177192688
# Epoch 194 - Training loss: 0.6248227953910828
# Epoch 194 - Test loss: 0.6583840847015381
# Epoch 195 - Training loss: 0.6114140152931213
# Epoch 195 - Test loss: 0.6452508568763733
# Epoch 196 - Training loss: 0.600041925907135
# Epoch 196 - Test loss: 0.6352670192718506
# Epoch 197 - Training loss: 0.5889437198638916
# Epoch 197 - Test loss: 0.6348363757133484
# Epoch 198 - Training loss: 0.5807692408561707
# Epoch 198 - Test loss: 0.630931556224823
# Epoch 199 - Training loss: 0.5727075934410095
# Epoch 199 - Test loss: 0.6249613165855408

# %%
def update_learning_rate(i, splitNN):
    lr_a = 0.3
    if i > 200:
        lr_a = 0.05
    if i > 400:
        lr_a = 0.01
    if i > 500:
        lr_a = 0.001
    optimizers = [
        (optim.SGD(models[location.id].parameters(), lr=lr_a,), location)
        for location in model_locations
    ]
    
    splitNN.set_lr(optimizers)
    return

EPOCHS = 200
SUBSET_UPDATE_PROB = 0.2
PADDING_METHOD = "wei"
LEARNING_RATE = 0.3
GROUP_TESTING_ROUNDS = 5
res = []

import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
from torch import nn, optim
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor

import syft as sy
import random
from time import process_time

from src.psi.util import Client, Server
from src.discrete_splitnn import DiscreteSplitNN
from src.utils import add_ids
from src.discrete_distribute_data import DiscreteDistributeMNIST

hook = sy.TorchHook(torch)

# Data preprocessing
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])
trainset = datasets.MNIST('mnist', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64
                                          , shuffle=True)

# create some workers
client_1 = sy.VirtualWorker(hook, id="client_1")
client_2 = sy.VirtualWorker(hook, id="client_2")
client_3 = sy.VirtualWorker(hook, id="client_3")
client_4 = sy.VirtualWorker(hook, id="client_4")
server = sy.VirtualWorker(hook, id= "server") 

data_owners = (client_1, client_2, client_3, client_4)
model_locations = [client_1, client_2, client_3, client_4, server]

#Split each image and send one part to client_1, and other to client_2
distributed_trainloader = DiscreteDistributeMNIST(data_owners=data_owners, data_loader=trainloader)

torch.manual_seed(0)

# Define our model segments

input_size= [28*7, 28*7, 28*7, 28*7]
hidden_sizes= {"client_1": [128, 64], "client_2":[128, 64], "client_3": [128, 64], "client_4":[128, 64], "server":[256, 128]}
output_size = 10

models = {
    "client_1": nn.Sequential(
                nn.Linear(input_size[0], hidden_sizes["client_1"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_1"][0], hidden_sizes["client_1"][1]),
                nn.ReLU(),
    ),
    "client_2":  nn.Sequential(
                nn.Linear(input_size[1], hidden_sizes["client_2"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_2"][0], hidden_sizes["client_2"][1]),
                nn.ReLU(),
    ),
    "client_3":  nn.Sequential(
                nn.Linear(input_size[2], hidden_sizes["client_3"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_3"][0], hidden_sizes["client_3"][1]),
                nn.ReLU(),
    ),
    "client_4":  nn.Sequential(
                nn.Linear(input_size[3], hidden_sizes["client_4"][0]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["client_4"][0], hidden_sizes["client_4"][1]),
                nn.ReLU(),
    ),
    "server": nn.Sequential(
                nn.Linear(hidden_sizes["server"][0], hidden_sizes["server"][1]),
                nn.ReLU(),
                nn.Linear(hidden_sizes["server"][1], 10),
                nn.LogSoftmax(dim=1)
    )
}

# Create optimisers for each segment and link to them
optimizers = [
    (optim.SGD(models[location.id].parameters(), lr=LEARNING_RATE,), location)
    for location in model_locations
]

for location in model_locations:
    models[location.id].send(location)


#Instantiate a SpliNN class with our distributed segments and their respective optimizers
splitNN = DiscreteSplitNN(models, server, data_owners, optimizers, distributed_trainloader, k=10, n_selected=2, padding_method=PADDING_METHOD)

distributed_trainloader.generate_subdata()
s = process_time()
splitNN.group_testing(GROUP_TESTING_ROUNDS)
print('group testing: ' + str(process_time() - s))
test_perf = []
performance = []
print(len(distributed_trainloader.distributed_subdata))
print(len(distributed_trainloader.test_set))
for i in range(EPOCHS):
    s = process_time()
    if (i > 0) and (i % 5000 == 0):
        plt.plot(range(1, i+1), performance)
        plt.ylabel('Training loss')
        plt.xlabel('Epoch')
        plt.ylim([0,2.5])
        plt.show()

        plt.plot(range(1, i+1), test_perf)
        plt.ylabel('Test loss')
        plt.xlabel('Epoch')
        plt.ylim([0,2.5])
        plt.show()
    running_loss = 0
    test_loss = 0
    if (random.random() < SUBSET_UPDATE_PROB):
        distributed_trainloader.generate_subdata()
        splitNN.group_testing(GROUP_TESTING_ROUNDS)
    
    #iterate over each datapoint 
    for _, data_ptr, label in distributed_trainloader.distributed_subdata:
        
        #send labels to server's location for training
        label = label.send(server)
        
        loss = splitNN.train(data_ptr, label)
        running_loss += loss
    
    for data_ptr, label in distributed_trainloader.test_set:
        label = label.send(server)
        
        loss = splitNN.eval(data_ptr, label)
        test_loss += loss
    
    test_perf.append((test_loss/len(distributed_trainloader.test_set)).item())
    performance.append((running_loss/len(distributed_trainloader.distributed_subdata)).item())
    print("Epoch {} - Training loss: {}".format(i, running_loss/len(distributed_trainloader.distributed_subdata)))
    print("Epoch {} - Test loss: {}".format(i, test_loss/len(distributed_trainloader.test_set)))
    update_learning_rate(i, splitNN)


res.append(performance)
plt.plot(range(1, EPOCHS+1), performance)
plt.ylabel('Training loss')
plt.xlabel('Epoch')
plt.ylim([0,2.5])
plt.show()

plt.plot(range(1, EPOCHS+1), test_perf)
plt.ylabel('Test loss')
plt.xlabel('Epoch')
plt.ylim([0,2.5])
plt.show()
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process
# group testing: 6.912499975442188e-05
# 78
# 50
# Epoch 0 - Training loss: 2.2603485584259033
# Epoch 0 - Test loss: 2.183387517929077
# Epoch 1 - Training loss: 2.028553009033203
# Epoch 1 - Test loss: 1.8216919898986816
# Epoch 2 - Training loss: 1.676365613937378
# Epoch 2 - Test loss: 1.5269980430603027
# Epoch 3 - Training loss: 1.4304529428482056
# Epoch 3 - Test loss: 1.3634036779403687
# Epoch 4 - Training loss: 1.2769973278045654
# Epoch 4 - Test loss: 1.264845371246338
# Epoch 5 - Training loss: 1.178719401359558
# Epoch 5 - Test loss: 1.2028403282165527
# Epoch 6 - Training loss: 1.1120214462280273
# Epoch 6 - Test loss: 1.1580833196640015
# Epoch 7 - Training loss: 1.0626606941223145
# Epoch 7 - Test loss: 1.122694969177246
# Epoch 8 - Training loss: 1.0244667530059814
# Epoch 8 - Test loss: 1.0930808782577515
# Epoch 9 - Training loss: 0.9938793778419495
# Epoch 9 - Test loss: 1.0705647468566895
# Epoch 10 - Training loss: 0.9683111906051636
# Epoch 10 - Test loss: 1.0529412031173706
# Epoch 11 - Training loss: 1.199395775794983
# Epoch 11 - Test loss: 1.0856714248657227
# Epoch 12 - Training loss: 1.096342921257019
# Epoch 12 - Test loss: 1.0281091928482056
# Epoch 13 - Training loss: 1.04145348072052
# Epoch 13 - Test loss: 0.9874613285064697
# Epoch 14 - Training loss: 1.0021703243255615
# Epoch 14 - Test loss: 0.9625383019447327
# Epoch 15 - Training loss: 0.9701499342918396
# Epoch 15 - Test loss: 0.9389708042144775
# Epoch 16 - Training loss: 0.9426150918006897
# Epoch 16 - Test loss: 0.9217981696128845
# Epoch 17 - Training loss: 0.9194114208221436
# Epoch 17 - Test loss: 0.9071571826934814
# Epoch 18 - Training loss: 0.898561418056488
# Epoch 18 - Test loss: 0.8933303356170654
# Epoch 19 - Training loss: 0.8797043561935425
# Epoch 19 - Test loss: 0.8835259079933167
# Epoch 20 - Training loss: 1.9562991857528687
# Epoch 20 - Test loss: 1.666161060333252
# Epoch 21 - Training loss: 1.4834097623825073
# Epoch 21 - Test loss: 1.3875678777694702
# Epoch 22 - Training loss: 1.2915064096450806
# Epoch 22 - Test loss: 1.2587007284164429
# Epoch 23 - Training loss: 1.18666410446167
# Epoch 23 - Test loss: 1.1932246685028076
# Epoch 24 - Training loss: 1.1207298040390015
# Epoch 24 - Test loss: 1.1387690305709839
# Epoch 25 - Training loss: 1.07123863697052
# Epoch 25 - Test loss: 1.0992891788482666
# Epoch 26 - Training loss: 1.0319575071334839
# Epoch 26 - Test loss: 1.0667434930801392
# Epoch 27 - Training loss: 0.9991719722747803
# Epoch 27 - Test loss: 1.041853666305542
# Epoch 28 - Training loss: 0.9742550253868103
# Epoch 28 - Test loss: 1.0172028541564941
# Epoch 29 - Training loss: 1.2147499322891235
# Epoch 29 - Test loss: 1.0360277891159058
# Epoch 30 - Training loss: 0.9951075315475464
# Epoch 30 - Test loss: 0.9936235547065735
# Epoch 31 - Training loss: 0.9327483773231506
# Epoch 31 - Test loss: 0.9371507167816162
# Epoch 32 - Training loss: 0.8970500826835632
# Epoch 32 - Test loss: 0.9257259368896484
# Epoch 33 - Training loss: 0.6960719227790833
# Epoch 33 - Test loss: 0.6033514142036438
# Epoch 34 - Training loss: 0.6053767204284668
# Epoch 34 - Test loss: 0.5726272463798523
# Epoch 35 - Training loss: 0.5713932514190674
# Epoch 35 - Test loss: 0.552782416343689
# Epoch 36 - Training loss: 0.544434130191803
# Epoch 36 - Test loss: 0.5390241742134094
# Epoch 37 - Training loss: 0.5241817831993103
# Epoch 37 - Test loss: 0.5300739407539368
# Epoch 38 - Training loss: 0.5073438286781311
# Epoch 38 - Test loss: 0.5220575928688049
# Epoch 39 - Training loss: 1.0480482578277588
# Epoch 39 - Test loss: 0.9265087842941284
# Epoch 40 - Training loss: 0.9202868938446045
# Epoch 40 - Test loss: 0.8997811079025269
# Epoch 41 - Training loss: 0.8891232013702393
# Epoch 41 - Test loss: 0.8830453753471375
# Epoch 42 - Training loss: 0.8638994097709656
# Epoch 42 - Test loss: 0.8634800910949707
# Epoch 43 - Training loss: 0.8437092900276184
# Epoch 43 - Test loss: 0.8501299023628235
# Epoch 44 - Training loss: 0.8255195617675781
# Epoch 44 - Test loss: 0.8401525616645813
# Epoch 45 - Training loss: 0.8075741529464722
# Epoch 45 - Test loss: 0.8284334540367126
# Epoch 46 - Training loss: 0.7918769121170044
# Epoch 46 - Test loss: 0.8225465416908264
# Epoch 47 - Training loss: 2.089449644088745
# Epoch 47 - Test loss: 1.9970206022262573
# Epoch 48 - Training loss: 1.9452898502349854
# Epoch 48 - Test loss: 1.9313039779663086
# Epoch 49 - Training loss: 1.8701597452163696
# Epoch 49 - Test loss: 1.892975926399231
# Epoch 50 - Training loss: 1.8144665956497192
# Epoch 50 - Test loss: 1.8527706861495972
# Epoch 51 - Training loss: 1.7779773473739624
# Epoch 51 - Test loss: 1.8189764022827148
# Epoch 52 - Training loss: 1.1812440156936646
# Epoch 52 - Test loss: 1.0594433546066284
# Epoch 53 - Training loss: 1.0000172853469849
# Epoch 53 - Test loss: 0.9643743634223938
# Epoch 54 - Training loss: 0.9383094310760498
# Epoch 54 - Test loss: 0.9088301658630371
# Epoch 55 - Training loss: 0.897279679775238
# Epoch 55 - Test loss: 0.8831289410591125
# Epoch 56 - Training loss: 0.8636969923973083
# Epoch 56 - Test loss: 0.8431287407875061
# Epoch 57 - Training loss: 1.8396881818771362
# Epoch 57 - Test loss: 1.837101697921753
# Epoch 58 - Training loss: 1.7385669946670532
# Epoch 58 - Test loss: 1.814516544342041
# Epoch 59 - Training loss: 1.7342721223831177
# Epoch 59 - Test loss: 1.7390050888061523
# Epoch 60 - Training loss: 1.7060602903366089
# Epoch 60 - Test loss: 1.716978907585144
# Epoch 61 - Training loss: 0.8655792474746704
# Epoch 61 - Test loss: 0.8079665899276733
# Epoch 62 - Training loss: 0.7954349517822266
# Epoch 62 - Test loss: 0.7802153825759888
# Epoch 63 - Training loss: 0.7672151923179626
# Epoch 63 - Test loss: 0.7571986317634583
# Epoch 64 - Training loss: 0.9232685565948486
# Epoch 64 - Test loss: 0.9087963700294495
# Epoch 65 - Training loss: 0.8721467852592468
# Epoch 65 - Test loss: 0.8907621502876282
# Epoch 66 - Training loss: 0.8476043343544006
# Epoch 66 - Test loss: 0.8812324404716492
# Epoch 67 - Training loss: 0.8257691264152527
# Epoch 67 - Test loss: 0.871595561504364
# Epoch 68 - Training loss: 0.8089004755020142
# Epoch 68 - Test loss: 0.8571122884750366
# Epoch 69 - Training loss: 0.8001183867454529
# Epoch 69 - Test loss: 0.7678283452987671
# Epoch 70 - Training loss: 1.0447286367416382
# Epoch 70 - Test loss: 0.9243916869163513
# Epoch 71 - Training loss: 0.8711919188499451
# Epoch 71 - Test loss: 0.8710640668869019
# Epoch 72 - Training loss: 0.8294844627380371
# Epoch 72 - Test loss: 0.8399080634117126
# Epoch 73 - Training loss: 0.8059596419334412
# Epoch 73 - Test loss: 0.833365261554718
# Epoch 74 - Training loss: 0.7846104502677917
# Epoch 74 - Test loss: 0.8184673190116882
# Epoch 75 - Training loss: 0.7672886252403259
# Epoch 75 - Test loss: 0.8106841444969177
# Epoch 76 - Training loss: 0.7514069676399231
# Epoch 76 - Test loss: 0.7970938682556152
# Epoch 77 - Training loss: 0.7366377711296082
# Epoch 77 - Test loss: 0.789875328540802
# Epoch 78 - Training loss: 0.723351001739502
# Epoch 78 - Test loss: 0.7803549766540527
# Epoch 79 - Training loss: 0.7886975407600403
# Epoch 79 - Test loss: 0.8350951671600342
# Epoch 80 - Training loss: 0.9139952063560486
# Epoch 80 - Test loss: 0.8108019232749939
# Epoch 81 - Training loss: 0.8165103197097778
# Epoch 81 - Test loss: 0.7888767719268799
# Epoch 82 - Training loss: 0.7950742840766907
# Epoch 82 - Test loss: 0.7827206254005432
# Epoch 83 - Training loss: 0.7792002558708191
# Epoch 83 - Test loss: 0.7738243937492371
# Epoch 84 - Training loss: 0.7641021013259888
# Epoch 84 - Test loss: 0.7600263357162476
# Epoch 85 - Training loss: 0.7503740191459656
# Epoch 85 - Test loss: 0.7537181973457336
# Epoch 86 - Training loss: 0.7377767562866211
# Epoch 86 - Test loss: 0.7450413703918457
# Epoch 87 - Training loss: 0.7256053686141968
# Epoch 87 - Test loss: 0.7346439361572266
# Epoch 88 - Training loss: 0.7147985696792603
# Epoch 88 - Test loss: 0.7308794260025024
# Epoch 89 - Training loss: 0.7042537927627563
# Epoch 89 - Test loss: 0.7315647602081299
# Epoch 90 - Training loss: 0.6953199505805969
# Epoch 90 - Test loss: 0.724018931388855
# Epoch 91 - Training loss: 0.685494601726532
# Epoch 91 - Test loss: 0.7275021076202393
# Epoch 92 - Training loss: 0.6764810085296631
# Epoch 92 - Test loss: 0.7259680032730103
# Epoch 93 - Training loss: 0.6687050461769104
# Epoch 93 - Test loss: 0.7235921621322632
# Epoch 94 - Training loss: 0.6596993803977966
# Epoch 94 - Test loss: 0.7170283794403076
# Epoch 95 - Training loss: 0.6530041694641113
# Epoch 95 - Test loss: 0.7134017944335938
# Epoch 96 - Training loss: 0.6450868248939514
# Epoch 96 - Test loss: 0.7188802361488342
# Epoch 97 - Training loss: 0.6374804377555847
# Epoch 97 - Test loss: 0.7175938487052917
# Epoch 98 - Training loss: 0.6294424533843994
# Epoch 98 - Test loss: 0.7185621857643127
# Epoch 99 - Training loss: 0.6229925751686096
# Epoch 99 - Test loss: 0.718060314655304
# Epoch 100 - Training loss: 1.883300542831421
# Epoch 100 - Test loss: 1.784316062927246
# Epoch 101 - Training loss: 1.7609623670578003
# Epoch 101 - Test loss: 1.7399816513061523
# Epoch 102 - Training loss: 0.548302948474884
# Epoch 102 - Test loss: 0.49000683426856995
# Epoch 103 - Training loss: 0.44003617763519287
# Epoch 103 - Test loss: 0.4811968505382538
# Epoch 104 - Training loss: 0.40916329622268677
# Epoch 104 - Test loss: 0.47256943583488464
# Epoch 105 - Training loss: 0.38751718401908875
# Epoch 105 - Test loss: 0.4622672200202942
# Epoch 106 - Training loss: 1.7951627969741821
# Epoch 106 - Test loss: 1.717674732208252
# Epoch 107 - Training loss: 1.6825348138809204
# Epoch 107 - Test loss: 1.7150695323944092
# Epoch 108 - Training loss: 1.6719205379486084
# Epoch 108 - Test loss: 1.6924632787704468
# Epoch 109 - Training loss: 1.6571646928787231
# Epoch 109 - Test loss: 1.6879161596298218
# Epoch 110 - Training loss: 1.6369575262069702
# Epoch 110 - Test loss: 1.6816407442092896
# Epoch 111 - Training loss: 1.6257795095443726
# Epoch 111 - Test loss: 1.6698936223983765
# Epoch 112 - Training loss: 1.613168478012085
# Epoch 112 - Test loss: 1.6730750799179077
# Epoch 113 - Training loss: 1.6010322570800781
# Epoch 113 - Test loss: 1.6686595678329468
# Epoch 114 - Training loss: 1.5906167030334473
# Epoch 114 - Test loss: 1.6490478515625
# Epoch 115 - Training loss: 1.5821229219436646
# Epoch 115 - Test loss: 1.649969220161438
# Epoch 116 - Training loss: 1.5747859477996826
# Epoch 116 - Test loss: 1.649146556854248
# Epoch 117 - Training loss: 1.5699032545089722
# Epoch 117 - Test loss: 1.6594218015670776
# Epoch 118 - Training loss: 1.5586750507354736
# Epoch 118 - Test loss: 1.6514912843704224
# Epoch 119 - Training loss: 1.5522152185440063
# Epoch 119 - Test loss: 1.6341238021850586
# Epoch 120 - Training loss: 1.5434246063232422
# Epoch 120 - Test loss: 1.6293128728866577
# Epoch 121 - Training loss: 1.5403410196304321
# Epoch 121 - Test loss: 1.6303972005844116
# Epoch 122 - Training loss: 0.4908420145511627
# Epoch 122 - Test loss: 0.4363041818141937
# Epoch 123 - Training loss: 0.7430862784385681
# Epoch 123 - Test loss: 0.6498138308525085
# Epoch 124 - Training loss: 0.6728077530860901
# Epoch 124 - Test loss: 0.6261381506919861
# Epoch 125 - Training loss: 0.6471284627914429
# Epoch 125 - Test loss: 0.617635190486908
# Epoch 126 - Training loss: 0.6238654851913452
# Epoch 126 - Test loss: 0.597084641456604
# Epoch 127 - Training loss: 0.6055186986923218
# Epoch 127 - Test loss: 0.5857569575309753
# Epoch 128 - Training loss: 0.912307620048523
# Epoch 128 - Test loss: 0.8420061469078064
# Epoch 129 - Training loss: 0.78950434923172
# Epoch 129 - Test loss: 0.8407849669456482
# Epoch 130 - Training loss: 1.676242470741272
# Epoch 130 - Test loss: 1.7507195472717285
# Epoch 131 - Training loss: 1.606968641281128
# Epoch 131 - Test loss: 1.6682952642440796
# Epoch 132 - Training loss: 1.5990798473358154
# Epoch 132 - Test loss: 1.7316431999206543
# Epoch 133 - Training loss: 1.5839701890945435
# Epoch 133 - Test loss: 1.7530181407928467
# Epoch 134 - Training loss: 1.5756269693374634
# Epoch 134 - Test loss: 1.7090262174606323
# Epoch 135 - Training loss: 0.4816053807735443
# Epoch 135 - Test loss: 0.4320875108242035
# Epoch 136 - Training loss: 0.39527982473373413
# Epoch 136 - Test loss: 0.41516783833503723
# Epoch 137 - Training loss: 0.3730272352695465
# Epoch 137 - Test loss: 0.40172523260116577
# Epoch 138 - Training loss: 0.3569296598434448
# Epoch 138 - Test loss: 0.39131230115890503
# Epoch 139 - Training loss: 0.3437979519367218
# Epoch 139 - Test loss: 0.3842654526233673
# Epoch 140 - Training loss: 0.3325524628162384
# Epoch 140 - Test loss: 0.37951770424842834
# Epoch 141 - Training loss: 0.3217865824699402
# Epoch 141 - Test loss: 0.3744661211967468
# Epoch 142 - Training loss: 0.3122168481349945
# Epoch 142 - Test loss: 0.3707925081253052
# Epoch 143 - Training loss: 0.6587790846824646
# Epoch 143 - Test loss: 0.5962806344032288
# Epoch 144 - Training loss: 0.5821117162704468
# Epoch 144 - Test loss: 0.5916556715965271
# Epoch 145 - Training loss: 0.559195339679718
# Epoch 145 - Test loss: 0.5878329277038574
# Epoch 146 - Training loss: 0.5427389740943909
# Epoch 146 - Test loss: 0.5829787254333496
# Epoch 147 - Training loss: 0.5290991067886353
# Epoch 147 - Test loss: 0.5790610313415527
# Epoch 148 - Training loss: 0.5163953304290771
# Epoch 148 - Test loss: 0.5737364292144775
# Epoch 149 - Training loss: 0.8652775883674622
# Epoch 149 - Test loss: 0.8891675472259521
# Epoch 150 - Training loss: 0.7612940669059753
# Epoch 150 - Test loss: 0.8498377799987793
# Epoch 151 - Training loss: 0.7390670776367188
# Epoch 151 - Test loss: 0.8254257440567017
# Epoch 152 - Training loss: 0.7224671840667725
# Epoch 152 - Test loss: 0.8211650252342224
# Epoch 153 - Training loss: 0.7070439457893372
# Epoch 153 - Test loss: 0.8061302304267883
# Epoch 154 - Training loss: 0.6950770616531372
# Epoch 154 - Test loss: 0.7988007068634033
# Epoch 155 - Training loss: 0.6838626265525818
# Epoch 155 - Test loss: 0.7874349355697632
# Epoch 156 - Training loss: 0.6727820634841919
# Epoch 156 - Test loss: 0.7780229449272156
# Epoch 157 - Training loss: 0.6633294820785522
# Epoch 157 - Test loss: 0.7709084153175354
# Epoch 158 - Training loss: 0.6536773443222046
# Epoch 158 - Test loss: 0.7682121396064758
# Epoch 159 - Training loss: 0.6456679701805115
# Epoch 159 - Test loss: 0.7672749161720276
# Epoch 160 - Training loss: 0.6365161538124084
# Epoch 160 - Test loss: 0.7576375007629395
# Epoch 161 - Training loss: 0.6294853091239929
# Epoch 161 - Test loss: 0.7538003325462341
# Epoch 162 - Training loss: 0.6241137981414795
# Epoch 162 - Test loss: 0.7559806704521179
# Epoch 163 - Training loss: 0.6164539456367493
# Epoch 163 - Test loss: 0.7365272045135498
# Epoch 164 - Training loss: 0.6095254421234131
# Epoch 164 - Test loss: 0.7473698258399963
# Epoch 165 - Training loss: 0.6033773422241211
# Epoch 165 - Test loss: 0.7411461472511292
# Epoch 166 - Training loss: 0.597678542137146
# Epoch 166 - Test loss: 0.7418016791343689
# Epoch 167 - Training loss: 0.5910512208938599
# Epoch 167 - Test loss: 0.7404932975769043
# Epoch 168 - Training loss: 0.5848122239112854
# Epoch 168 - Test loss: 0.736177921295166
# Epoch 169 - Training loss: 0.5806203484535217
# Epoch 169 - Test loss: 0.7339625358581543
# Epoch 170 - Training loss: 0.5733677744865417
# Epoch 170 - Test loss: 0.7265955209732056
# Epoch 171 - Training loss: 0.56784987449646
# Epoch 171 - Test loss: 0.7365496754646301
# Epoch 172 - Training loss: 0.5635315179824829
# Epoch 172 - Test loss: 0.7323057651519775
# Epoch 173 - Training loss: 0.72708660364151
# Epoch 173 - Test loss: 0.5914111137390137
# Epoch 174 - Training loss: 0.40431976318359375
# Epoch 174 - Test loss: 0.39842137694358826
# Epoch 175 - Training loss: 0.3481923043727875
# Epoch 175 - Test loss: 0.3898204565048218
# Epoch 176 - Training loss: 0.3261355459690094
# Epoch 176 - Test loss: 0.37953850626945496
# Epoch 177 - Training loss: 1.6990422010421753
# Epoch 177 - Test loss: 1.7124501466751099
# Epoch 178 - Training loss: 1.6111701726913452
# Epoch 178 - Test loss: 1.6951708793640137
# Epoch 179 - Training loss: 1.5903518199920654
# Epoch 179 - Test loss: 1.67718505859375
# Epoch 180 - Training loss: 0.7184615135192871
# Epoch 180 - Test loss: 0.7529494762420654
# Epoch 181 - Training loss: 0.6611247658729553
# Epoch 181 - Test loss: 0.7567732930183411
# Epoch 182 - Training loss: 0.6454834342002869
# Epoch 182 - Test loss: 0.7386983633041382
# Epoch 183 - Training loss: 0.8077499866485596
# Epoch 183 - Test loss: 0.7763485908508301
# Epoch 184 - Training loss: 0.7420648336410522
# Epoch 184 - Test loss: 0.755948543548584
# Epoch 185 - Training loss: 0.7128576636314392
# Epoch 185 - Test loss: 0.7422910332679749
# Epoch 186 - Training loss: 0.6904118657112122
# Epoch 186 - Test loss: 0.7368394732475281
# Epoch 187 - Training loss: 0.672685444355011
# Epoch 187 - Test loss: 0.7339962720870972
# Epoch 188 - Training loss: 0.6565530896186829
# Epoch 188 - Test loss: 0.7266185879707336
# Epoch 189 - Training loss: 0.641933023929596
# Epoch 189 - Test loss: 0.7218258380889893
# Epoch 190 - Training loss: 0.6995341181755066
# Epoch 190 - Test loss: 0.5771547555923462
# Epoch 191 - Training loss: 0.7522253394126892
# Epoch 191 - Test loss: 0.6805133819580078
# Epoch 192 - Training loss: 0.6633982062339783
# Epoch 192 - Test loss: 0.6718413829803467
# Epoch 193 - Training loss: 0.6450217366218567
# Epoch 193 - Test loss: 0.6703941226005554
# Epoch 194 - Training loss: 0.6308421492576599
# Epoch 194 - Test loss: 0.6637706756591797
# Epoch 195 - Training loss: 0.708471417427063
# Epoch 195 - Test loss: 0.6985076069831848
# Epoch 196 - Training loss: 1.6531269550323486
# Epoch 196 - Test loss: 1.735831618309021
# Epoch 197 - Training loss: 1.5941166877746582
# Epoch 197 - Test loss: 1.7148088216781616
# Epoch 198 - Training loss: 1.5763325691223145
# Epoch 198 - Test loss: 1.6754121780395508
# Epoch 199 - Training loss: 1.5601592063903809
# Epoch 199 - Test loss: 1.6703948974609375
