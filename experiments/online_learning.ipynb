# %%
def update_learning_rate(i, splitNN):
    lr_a = 0.3
    if i > 200:
        lr_a = 0.05
    if i > 400:
        lr_a = 0.01
    if i > 500:
        lr_a = 0.001
    optimizers = [
        (optim.SGD(models[location.id].parameters(), lr=lr_a,), location)
        for location in model_locations
    ]
    
    splitNN.set_lr(optimizers)

    return

PREPROCESSING_EPOCHS = 5
LEARNING_EPOCHS = 5
SUBSET_UPDATE_PROB = 1
PADDING_METHOD = "zeros"
LEARNING_RATE = 0.3
GROUP_TESTING_ROUNDS = 5
TO_BE_SELECTED = 2
TESTS = 100
CHANGE_PROBABILITY = 1
res = []

import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
from torch import nn, optim
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor

import syft as sy
import random
from time import process_time

from src.psi.util import Client, Server
from src.discrete_splitnn import DiscreteSplitNN
from src.utils import add_ids
from src.discrete_distribute_data import DiscreteDistributeMNIST

hook = sy.TorchHook(torch)

# Data preprocessing
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])
trainset = datasets.MNIST('mnist', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64
                                          , shuffle=True)

# create some workers
client_1 = sy.VirtualWorker(hook, id="client_1")
client_2 = sy.VirtualWorker(hook, id="client_2")
client_3 = sy.VirtualWorker(hook, id="client_3")
client_4 = sy.VirtualWorker(hook, id="client_4")
server = sy.VirtualWorker(hook, id= "server") 

data_owners = (client_1, client_2, client_3, client_4)
model_locations = [client_1, client_2, client_3, client_4, server]

#Split each image and send one part to client_1, and other to client_2
distributed_trainloader = DiscreteDistributeMNIST(data_owners=data_owners, data_loader=trainloader)

torch.manual_seed(0)

# Define our model segments

input_size= [28*7, 28*7, 28*7, 28*7]
hidden_sizes= {"client_1": [128, 64], "client_2":[128, 64], "client_3": [128, 64], "client_4":[128, 64], "server":[256, 128]}
output_size = 10

counters = {own: 0 for own in hidden_sizes}    
scores_lists = {own: [] for own in hidden_sizes}

for _ in range(TESTS):

    models = {
        "client_1": nn.Sequential(
                    nn.Linear(input_size[0], hidden_sizes["client_1"][0]),
                    nn.ReLU(),
                    nn.Linear(hidden_sizes["client_1"][0], hidden_sizes["client_1"][1]),
                    nn.ReLU(),
        ),
        "client_2":  nn.Sequential(
                    nn.Linear(input_size[1], hidden_sizes["client_2"][0]),
                    nn.ReLU(),
                    nn.Linear(hidden_sizes["client_2"][0], hidden_sizes["client_2"][1]),
                    nn.ReLU(),
        ),
        "client_3":  nn.Sequential(
                    nn.Linear(input_size[2], hidden_sizes["client_3"][0]),
                    nn.ReLU(),
                    nn.Linear(hidden_sizes["client_3"][0], hidden_sizes["client_3"][1]),
                    nn.ReLU(),
        ),
        "client_4":  nn.Sequential(
                    nn.Linear(input_size[3], hidden_sizes["client_4"][0]),
                    nn.ReLU(),
                    nn.Linear(hidden_sizes["client_4"][0], hidden_sizes["client_4"][1]),
                    nn.ReLU(),
        ),
        "server": nn.Sequential(
                    nn.Linear(hidden_sizes["server"][0], hidden_sizes["server"][1]),
                    nn.ReLU(),
                    nn.Linear(hidden_sizes["server"][1], 10),
                    nn.LogSoftmax(dim=1)
        )
    }

    # Create optimisers for each segment and link to them
    optimizers = [
        (optim.SGD(models[location.id].parameters(), lr=LEARNING_RATE,), location)
        for location in model_locations
    ]

    for location in model_locations:
        models[location.id].send(location)

    #Instantiate a SpliNN class with our distributed segments and their respective optimizers
    splitNN = DiscreteSplitNN(models, server, data_owners, optimizers, distributed_trainloader, k=10, n_selected=2, padding_method=PADDING_METHOD)
    distributed_trainloader.generate_subdata()

    test_perf = []
    performance = []

    splitNN.group_testing(GROUP_TESTING_ROUNDS)

    for i in range(PREPROCESSING_EPOCHS):
        running_loss = 0
        test_loss = 0
        if (random.random() < CHANGE_PROBABILITY):
            splitNN.group_testing(GROUP_TESTING_ROUNDS)

        #iterate over each datapoint 
        for _, data_ptr, label in distributed_trainloader.distributed_subdata:

            #send labels to server's location for training
            label = label.send(server)

            loss = splitNN.train(data_ptr, label)
            running_loss += loss


        performance.append((running_loss/len(distributed_trainloader.distributed_subdata)).item())
        
    losses = {}
    for own in splitNN.selected:
        losses[own] = []

    for i in range(LEARNING_EPOCHS):
        running_loss = 0
        test_loss = 0
        if (random.random() < CHANGE_PROBABILITY):
            splitNN.group_testing(GROUP_TESTING_ROUNDS)

        #iterate over each datapoint 
        for _, data_ptr, label in distributed_trainloader.distributed_subdata:

            #send labels to server's location for training
            label = label.send(server)

            loss = splitNN.train(data_ptr, label)
            running_loss += loss

        performance.append((running_loss/len(distributed_trainloader.distributed_subdata)).item())

        for own in splitNN.selected:
            if splitNN.selected[own]:
                losses[own].append( (running_loss/len(distributed_trainloader.distributed_subdata)).item() )


    scores = {own: sum(losses[own]) / len(losses[own]) if len(losses) > 0 else 0 for own in losses}
    for own in splitNN.selected:
        splitNN.selected[own] = False
        scores_lists[own].append(scores[own])

    for k in range(TO_BE_SELECTED):
        min_so_far = 0
        lo = float('inf')
        for i in scores:
            if scores[i] < lo:
                lo = scores[i]
                min_so_far = i

        splitNN.selected[min_so_far] = True
        scores.pop(min_so_far)
        counters[min_so_far] += 1    
    
    print(counters)

print('===FINAL RESULTS===')
for own in hidden_sizes:
    print(own)
    print('counter: ' + str(counters[own]))
    mean = sum(scores_lists[own]) / len(scores_lists[own])
    print('mean: ' + str(mean))
    sd = sum( [(i - mean) * (i - mean) for i in scores_lists[own]] ) / len(scores_lists[own])
    print('sd: ' + str(sd))
    print(scores_lists[own])
    print('min: ' + str(min(scores_lists[own])))
    print('max: ' + str(max(scores_lists[own])))
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process
# {'client_1': 0, 'client_2': 1, 'client_3': 1, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 2, 'client_3': 2, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 3, 'client_3': 3, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 4, 'client_3': 4, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 5, 'client_3': 5, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 6, 'client_3': 6, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 7, 'client_3': 7, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 8, 'client_3': 8, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 9, 'client_3': 9, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 10, 'client_3': 10, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 11, 'client_3': 11, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 12, 'client_3': 12, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 13, 'client_3': 13, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 14, 'client_3': 14, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 15, 'client_3': 15, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 16, 'client_3': 16, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 17, 'client_3': 17, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 18, 'client_3': 18, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 19, 'client_3': 19, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 20, 'client_3': 20, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 21, 'client_3': 21, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 22, 'client_3': 22, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 23, 'client_3': 23, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 24, 'client_3': 24, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 25, 'client_3': 25, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 26, 'client_3': 26, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 27, 'client_3': 27, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 28, 'client_3': 28, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 29, 'client_3': 29, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 30, 'client_3': 30, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 31, 'client_3': 31, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 32, 'client_3': 32, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 33, 'client_3': 33, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 34, 'client_3': 34, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 35, 'client_3': 35, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 36, 'client_3': 36, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 37, 'client_3': 37, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 38, 'client_3': 38, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 39, 'client_3': 39, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 40, 'client_3': 40, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 41, 'client_3': 41, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 42, 'client_3': 42, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 43, 'client_3': 43, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 44, 'client_3': 44, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 45, 'client_3': 45, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 46, 'client_3': 46, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 47, 'client_3': 47, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 48, 'client_3': 48, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 49, 'client_3': 49, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 50, 'client_3': 50, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 51, 'client_3': 51, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 52, 'client_3': 52, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 53, 'client_3': 53, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 54, 'client_3': 54, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 55, 'client_3': 55, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 56, 'client_3': 56, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 57, 'client_3': 57, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 58, 'client_3': 58, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 59, 'client_3': 59, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 60, 'client_3': 60, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 61, 'client_3': 61, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 62, 'client_3': 62, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 63, 'client_3': 63, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 64, 'client_3': 64, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 65, 'client_3': 65, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 66, 'client_3': 66, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 67, 'client_3': 67, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 68, 'client_3': 68, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 69, 'client_3': 69, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 70, 'client_3': 70, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 71, 'client_3': 71, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 72, 'client_3': 72, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 73, 'client_3': 73, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 74, 'client_3': 74, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 75, 'client_3': 75, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 76, 'client_3': 76, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 77, 'client_3': 77, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 78, 'client_3': 78, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 79, 'client_3': 79, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 80, 'client_3': 80, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 81, 'client_3': 81, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 82, 'client_3': 82, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 83, 'client_3': 83, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 84, 'client_3': 84, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 85, 'client_3': 85, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 86, 'client_3': 86, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 87, 'client_3': 87, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 88, 'client_3': 88, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 89, 'client_3': 89, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 90, 'client_3': 90, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 91, 'client_3': 91, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 92, 'client_3': 92, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 93, 'client_3': 93, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 94, 'client_3': 94, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 95, 'client_3': 95, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 96, 'client_3': 96, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 97, 'client_3': 97, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 98, 'client_3': 98, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 99, 'client_3': 99, 'client_4': 0, 'server': 0}
# {'client_1': 0, 'client_2': 100, 'client_3': 100, 'client_4': 0, 'server': 0}
# ===FINAL RESULTS===
# client_1
# counter: 0
# mean: 1.803806588947773
# sd: 0.0015643322050608154
# [1.778023600578308, 1.7611633837223053, 1.7644803822040558, 1.8063316345214844, 1.8259119093418121, 1.8592622578144073, 1.7580150663852692, 1.791464388370514, 1.783022403717041, 1.7978535592556, 1.7807420492172241, 1.841166615486145, 1.788366436958313, 1.807713508605957, 1.7334665656089783, 1.762641578912735, 1.7531248331069946, 1.7999617755413055, 1.8286373019218445, 1.8880431652069092, 1.8730214834213257, 1.8377076387405396, 1.8151303827762604, 1.8150821328163147, 1.805629849433899, 1.7850456535816193, 1.902721345424652, 1.8243060111999512, 1.860244631767273, 1.8882298171520233, 1.7635553181171417, 1.8601745069026947, 1.8112854957580566, 1.8600928485393524, 1.7759300470352173, 1.7365612983703613, 1.799257904291153, 1.7757077813148499, 1.7575417459011078, 1.7629183232784271, 1.8366855084896088, 1.8687607049942017, 1.7524787187576294, 1.7857889533042908, 1.8227581083774567, 1.7866957485675812, 1.768449455499649, 1.8312079012393951, 1.8068321645259857, 1.8192241191864014, 1.8529229164123535, 1.7487054765224457, 1.7961435317993164, 1.8510928750038147, 1.7913467288017273, 1.8227104544639587, 1.8471862375736237, 1.7898477613925934, 1.8468247652053833, 1.7835672795772552, 1.8650940358638763, 1.7713697850704193, 1.7825294733047485, 1.8328731060028076, 1.8486075699329376, 1.804353654384613, 1.7771423757076263, 1.7970845699310303, 1.833520621061325, 1.7691096365451813, 1.7659370005130768, 1.8217167854309082, 1.8737333714962006, 1.7571946382522583, 1.7908766269683838, 1.8062334954738617, 1.765188843011856, 1.8168112337589264, 1.796951562166214, 1.7295049130916595, 1.8071456849575043, 1.8310371935367584, 1.8234577178955078, 1.8262779712677002, 1.8354105651378632, 1.8286746740341187, 1.809399038553238, 1.7096559405326843, 1.7922875583171844, 1.8337063789367676, 1.8011887073516846, 1.7549123167991638, 1.838413953781128, 1.7423911690711975, 1.7769882380962372, 1.7626906037330627, 1.8140106499195099, 1.820223867893219, 1.7175374031066895, 1.8206499218940735]
# min: 1.7096559405326843
# max: 1.902721345424652
# client_2
# counter: 100
# mean: 1.2297810101509095
# sd: 0.006891746083274874
# [1.2811640501022339, 1.1215189695358276, 1.1055201292037964, 1.126423716545105, 1.2463661432266235, 1.3741629123687744, 1.1781502962112427, 1.157612919807434, 1.1189759969711304, 1.2260994911193848, 1.07515549659729, 1.3320919275283813, 1.3061223030090332, 1.2647463083267212, 1.0571972131729126, 1.2427372932434082, 1.194640874862671, 1.2528008222579956, 1.2754274606704712, 1.2652523517608643, 1.2709766626358032, 1.1841386556625366, 1.3999011516571045, 1.2041836977005005, 1.1744604110717773, 1.195864200592041, 1.3055295944213867, 1.1887233257293701, 1.3039474487304688, 1.310179352760315, 1.2896912097930908, 1.318569302558899, 1.301484227180481, 1.2962404489517212, 1.1547569036483765, 1.1968441009521484, 1.2670937776565552, 1.1186262369155884, 1.1722410917282104, 1.1101011037826538, 1.2764183282852173, 1.3804683685302734, 1.135666012763977, 1.2806819677352905, 1.3032780885696411, 1.2926733493804932, 1.2796101570129395, 1.2533254623413086, 1.1888763904571533, 1.2120542526245117, 1.4384875297546387, 1.3015289306640625, 1.180712103843689, 1.1182162761688232, 1.1530532836914062, 1.2199074029922485, 1.311177134513855, 1.1810890436172485, 1.4279743432998657, 1.210036277770996, 1.215937614440918, 1.1462069749832153, 1.2454739809036255, 1.2014979124069214, 1.2736833095550537, 1.21413254737854, 1.1374948024749756, 1.2788994312286377, 1.2826268672943115, 1.1481397151947021, 1.2072993516921997, 1.1887515783309937, 1.4734700918197632, 1.2820775508880615, 1.2287261486053467, 1.3126214742660522, 1.2278342247009277, 1.3079222440719604, 1.2673101425170898, 1.192541480064392, 1.114478349685669, 1.2561107873916626, 1.237964391708374, 1.1273620128631592, 1.1699572801589966, 1.365585446357727, 1.2166259288787842, 1.117247462272644, 1.2349909543991089, 1.2038546800613403, 1.2228354215621948, 1.028232455253601, 1.1859923601150513, 1.1538656949996948, 1.2427576780319214, 1.139691948890686, 1.2876960039138794, 1.2300487756729126, 1.1654722690582275, 1.3337293863296509]
# min: 1.028232455253601
# max: 1.4734700918197632
# client_3
# counter: 100
# mean: 1.2641597712039947
# sd: 0.005349452648399009
# [1.2125582695007324, 1.1185051202774048, 1.1763765811920166, 1.27632737159729, 1.2981650829315186, 1.38430655002594, 1.2062877416610718, 1.2304861545562744, 1.1939390897750854, 1.221094012260437, 1.2580360174179077, 1.3408796787261963, 1.263587236404419, 1.319389820098877, 1.1063802242279053, 1.2042464017868042, 1.2287616729736328, 1.315468430519104, 1.2271077632904053, 1.4464939832687378, 1.3931219577789307, 1.3587373495101929, 1.3288737535476685, 1.241642713546753, 1.269486427307129, 1.2497868537902832, 1.3991328477859497, 1.3057713508605957, 1.416886568069458, 1.3925530910491943, 1.2253127098083496, 1.27302086353302, 1.2996917963027954, 1.3869446516036987, 1.2145076990127563, 1.2109668254852295, 1.2611939907073975, 1.3089160919189453, 1.22031569480896, 1.237136721611023, 1.3117859363555908, 1.3486608266830444, 1.2566577196121216, 1.1807403564453125, 1.3040369749069214, 1.1620097160339355, 1.2254517078399658, 1.2695170640945435, 1.3062164783477783, 1.2772717475891113, 1.3924221992492676, 1.133815884590149, 1.2191886901855469, 1.4045253992080688, 1.2085471153259277, 1.3036717176437378, 1.3014918565750122, 1.2922180891036987, 1.2340967655181885, 1.2809531688690186, 1.291387915611267, 1.1526294946670532, 1.2410459518432617, 1.2968862056732178, 1.300917148590088, 1.2829416990280151, 1.222370982170105, 1.2895082235336304, 1.2233507633209229, 1.239805817604065, 1.2292859554290771, 1.292618751525879, 1.435654640197754, 1.1838302612304688, 1.2224041223526, 1.287600040435791, 1.2899409532546997, 1.2578641176223755, 1.1319535970687866, 1.1214061975479126, 1.2835108041763306, 1.3516453504562378, 1.2385815382003784, 1.2547550201416016, 1.277840495109558, 1.2501749992370605, 1.2228707075119019, 1.1168293952941895, 1.3356391191482544, 1.309871792793274, 1.2247189283370972, 1.2295304536819458, 1.2897905111312866, 1.1549431085586548, 1.244111180305481, 1.2117632627487183, 1.2081456184387207, 1.3110235929489136, 1.130605697631836, 1.3405461311340332]
# min: 1.1063802242279053
# max: 1.4464939832687378
# client_4
# counter: 0
# mean: 1.7952118986845016
# sd: 0.0017349662317563237
# [1.7951750457286835, 1.761916846036911, 1.7467662692070007, 1.768855720758438, 1.8129621744155884, 1.856726348400116, 1.750980705022812, 1.7732460796833038, 1.7642816305160522, 1.799104928970337, 1.7350219190120697, 1.8389696776866913, 1.7990002036094666, 1.794052630662918, 1.72117081284523, 1.772264301776886, 1.7445946335792542, 1.7842948734760284, 1.840717226266861, 1.8427327573299408, 1.8424851596355438, 1.7940579652786255, 1.8328872323036194, 1.8057173788547516, 1.781873345375061, 1.7715649902820587, 1.8793205320835114, 1.7950440049171448, 1.8320098519325256, 1.8676363825798035, 1.779649943113327, 1.8715616166591644, 1.811733603477478, 1.837416797876358, 1.7609923481941223, 1.733030617237091, 1.8007328510284424, 1.7281353175640106, 1.7455230951309204, 1.7311594188213348, 1.8278436064720154, 1.876712590456009, 1.7222307920455933, 1.8107743561267853, 1.8225683867931366, 1.8193616569042206, 1.7819890677928925, 1.8271600008010864, 1.7774971425533295, 1.8029197454452515, 1.8644392490386963, 1.790633738040924, 1.786524385213852, 1.7795155942440033, 1.777473270893097, 1.8017693758010864, 1.8496075570583344, 1.7620655000209808, 1.8952941596508026, 1.7658380568027496, 1.846231460571289, 1.7697641551494598, 1.7836364805698395, 1.8090260326862335, 1.841799110174179, 1.7871513664722443, 1.755923330783844, 1.794432371854782, 1.8483396470546722, 1.7461931109428406, 1.7604403495788574, 1.795749992132187, 1.8831872344017029, 1.7817564606666565, 1.7924571335315704, 1.812488853931427, 1.749662160873413, 1.8293257653713226, 1.8307906985282898, 1.7472887337207794, 1.7648875713348389, 1.8071535527706146, 1.8233034312725067, 1.7944297194480896, 1.8084397614002228, 1.8575272858142853, 1.8078378438949585, 1.709760457277298, 1.767125517129898, 1.8072021007537842, 1.800717830657959, 1.7045878171920776, 1.812464416027069, 1.7421218156814575, 1.7766498625278473, 1.7446727752685547, 1.8338982462882996, 1.7999801635742188, 1.7262540459632874, 1.818945735692978]
# min: 1.7045878171920776
# max: 1.8952941596508026
# server
# counter: 0
# mean: 1.6890014731884002
# sd: 0.0018500697630636793
# [1.6786516904830933, 1.6332345008850098, 1.632688331604004, 1.6703500509262086, 1.7100027561187745, 1.7622423887252807, 1.6420421123504638, 1.6646940946578979, 1.6502131223678589, 1.683502745628357, 1.6396247386932372, 1.7393516778945923, 1.691917610168457, 1.6991200685501098, 1.5982126951217652, 1.6586607217788696, 1.64142804145813, 1.6905295848846436, 1.7179953336715699, 1.7634850025177002, 1.7526125192642212, 1.7069938421249389, 1.732084536552429, 1.6929024457931519, 1.6793959617614747, 1.6672093629837037, 1.783282995223999, 1.6971894741058349, 1.748985195159912, 1.7726197242736816, 1.6687824964523315, 1.7518534660339355, 1.7093252420425415, 1.7473223686218262, 1.6516954183578492, 1.6286178588867188, 1.6928250789642334, 1.6442914724349975, 1.6404816150665282, 1.6323548793792724, 1.7246320724487305, 1.771102237701416, 1.629116177558899, 1.6847675561904907, 1.7188621044158936, 1.6878912687301635, 1.6706815958023071, 1.7156314134597779, 1.6832410097122192, 1.6977901458740234, 1.7700358390808106, 1.659270167350769, 1.673057246208191, 1.7045175552368164, 1.6636880397796632, 1.7021498441696168, 1.7399844169616698, 1.6680960178375244, 1.7630546808242797, 1.6688610792160035, 1.7352627515792847, 1.6463372230529785, 1.675118374824524, 1.7065980672836303, 1.7336227178573609, 1.6863094329833985, 1.649212861061096, 1.6934475421905517, 1.7233418703079224, 1.6449156522750854, 1.6542094707489015, 1.6951237440109252, 1.7936807155609131, 1.662171220779419, 1.6784465312957764, 1.7075110912322997, 1.6577179193496705, 1.7150334358215331, 1.6910232782363892, 1.622112226486206, 1.6686122179031373, 1.7160519123077393, 1.706359052658081, 1.686494779586792, 1.7023199081420899, 1.7360568284988402, 1.6908444166183472, 1.5911742448806763, 1.6808282375335692, 1.707736039161682, 1.6855180501937865, 1.6095763444900513, 1.7079296350479125, 1.624686074256897, 1.670142126083374, 1.6380908727645873, 1.7087477207183839, 1.7021888494491577, 1.6071243762969971, 1.723265814781189]
# min: 1.5911742448806763
# max: 1.7936807155609131
